# %%
import healpy as hp
import matplotlib.pyplot as plt

# Generate some data
nside = 16
m = [i for i in range(5)]

# Create a figure and axis object using healpy.graticule()
fig, ax = hp.graticule()

# Plot the data using healpy.mollview()
hp.mollview(m, sub=ax)

# Show the plot
plt.show()
# Out:
# /lustre/fs22/group/hess/user/wybouwt/conda/gammatransients/lib/python3.9/site-packages/healpy/visufunc.py:1505: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   pylab.draw()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /afs/ifh.de/user/w/wybouwt/git/gamma_transients/testing/healpy.ipynb Cell 1 in <cell line: 9>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bhess-wgs2/afs/ifh.de/user/w/wybouwt/git/gamma_transients/testing/healpy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> m = [i for i in range(5)]
#       <a href='vscode-notebook-cell://ssh-remote%2Bhess-wgs2/afs/ifh.de/user/w/wybouwt/git/gamma_transients/testing/healpy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # Create a figure and axis object using healpy.graticule()
# ...
