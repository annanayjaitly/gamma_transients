# %%
import numpy as np

# %%
myarrays = np.load("./mc_scanner/MC_dumps/dwarf/N3_da(0.2)_dt(3000.0 ms)/da_dt_6492f2991294.npz")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3))
h = plt.hist(myarrays["dt"],histtype="step")
plt.xlabel("dt [ns]")
plt.ylabel("Counts")
plt.title("MC Population")
# Out:
# Text(0.5, 1.0, 'MC Population')

# %%
from regions import CircleSkyRegion, RectangleSkyRegion
from astropy.coordinates import SkyCoord
import astropy.units as u
from gammapy.maps import RegionGeom

# %%
center= SkyCoord(283.775,-31.1833,unit="deg",frame="fk5")
circle = CircleSkyRegion(center,0.1 * u.deg)
rect = RectangleSkyRegion(center,5 * u.deg,5 * u.deg)
rg_c = RegionGeom(circle)
rg_r = RegionGeom(rect)

rg_r.solid_angle()/rg_c.solid_angle()
# Out:
# <Quantity 795.77471546>

# %%
import dill
from gammapy.datasets import MapDataset
with open("mc_scanner/real_dataset_dumps/dwarf/stacked_datasets.pkl","rb") as f:
    myob: MapDataset = dill.load(f)

# %%
print(myob.exposure)
# Out:
# WcsNDMap
#
# 	geom  : WcsGeom
#  	axes  : ['lon', 'lat', 'energy_true']
# 	shape : (250, 250, 30)
# 	ndim  : 3
# 	unit  : m2 s
# 	dtype : float32

# %%
myob.peek()
# Out:
# /lustre/fs22/group/hess/user/wybouwt/conda/gammatransients/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   func(*args, **kwargs)
# /lustre/fs22/group/hess/user/wybouwt/conda/gammatransients/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
teehee = myob.exposure.cumsum(axis_name="energy_true")

# %%
teehee.data[-1].shape
# Out:
# (250, 250)

# %%
import dill
with open("mc_scanner/real_dataset_dumps/")
